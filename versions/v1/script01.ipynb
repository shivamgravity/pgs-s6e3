# %% [markdown]
# # Let's Start with Baseline Model
# ## Logistic Regression
#
# Alright, here we go...
#
# What is linear regression?
#
# It tries to find the linear relationship between the data points of the two axis on the graph.

# %%
# import required librarires
